# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# Importa la classe dal progetto
from crop_p.models import Plant

# Crea alcune piante
pomodoro = Plant("Pomodoro", "Estate", 90, 0.2, 3.0)
lattuga = Plant("Lattuga", "Primavera", 45, 0.1, 0.3)

# Mostra descrizione
pomodoro.plant_description()

# Mostra lista verdura
Plant.get_total_plants()
# Out:
# plant's name: Pomodoro, plant's season: Estate
# 4
