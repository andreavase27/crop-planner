# %% [markdown]
# # Crop Planner: Vegetable Garden Simulation
#
# This notebook presents a simulation of a small-scale vegetable garden
# based on the available area, growing season, and number of people.
# The model selects plants suitable for the chosen season,
# estimates their required area, expected yield, and growth time
# using the Plant and Garden classes.
