# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# Importa la classe dal progetto
from crop_p.models import Plant

# Crea alcune piante
pomodoro = Plant("Pomodoro", "Estate", 90, 0.2, 3.0)
lattuga = Plant("Lattuga", "Primavera", 45, 0.1, 0.3)

# Mostra descrizione
print(pomodoro.describe())
print(lattuga.describe())
# Out:
# Pomodoro (Estate) - 90 giorni | area/pianta: 0.20 m² | resa: 3.00 kg
# Lattuga (Primavera) - 45 giorni | area/pianta: 0.10 m² | resa: 0.30 kg
